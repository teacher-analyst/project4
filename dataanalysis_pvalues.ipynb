# %%
import pandas as pd


crashes_df = pd.read_csv("Resources\Road_Crashes_for_five_Years_Victoria.csv")
crashes_df.head()
# Out:
#              X            Y  OBJECTID   ACCIDENT_NO                 ABS_CODE  \
# 0  2444652.517  2369157.816         1  T20150013818  ABS to receive accident
# 1  2507053.522  2427188.691         2  T20150013844  ABS to receive accident
# 2  2490706.473  2409439.682         3  T20150013854  ABS to receive accident
# 3  2524370.961  2379929.797         4  T20150013897         Non ABS accident
# 4  2346439.879  2385852.164         5  T20150013907  ABS to receive accident
#
#   ACCIDENT_STATUS ACCIDENT_DATE ACCIDENT_TIME ALCOHOLTIME  \
# 0        Finished     1/07/2015   05:15:00+00         Yes
# 1        Finished     1/07/2015   11:30:00+00          No
# 2        Finished     1/07/2015   13:40:00+00          No
# 3        Finished     2/07/2015   10:31:00+00          No
# 4        Finished     2/07/2015   10:25:00+00          No
#
#                        ACCIDENT_TYPE  ...            DEG_URBAN_ALL  \
# 0      Collision with a fixed object  ...  LARGE_PROVINCIAL_CITIES
# ...

# %%
crashes_cleaned_df = crashes_df.drop(columns=["X", "Y", "SRNS", "SRNS_ALL", "PED_CYCLIST_13_18", "PED_CYCLIST_5_12", "UNKNOWN", "PEDESTRIAN", "DRIVER", "PASSENGER", "BICYCLIST", "VICGRID_X", "VICGRID_Y", "NODE_ID", "OBJECTID", "ACCIDENT_NO", "ABS_CODE"])

# %%
crashes_cleaned_df.head()
# Out:
#   ACCIDENT_STATUS ACCIDENT_DATE ACCIDENT_TIME ALCOHOLTIME  \
# 0        Finished     1/07/2015   05:15:00+00         Yes
# 1        Finished     1/07/2015   11:30:00+00          No
# 2        Finished     1/07/2015   13:40:00+00          No
# 3        Finished     2/07/2015   10:31:00+00          No
# 4        Finished     2/07/2015   10:25:00+00          No
#
#                        ACCIDENT_TYPE  DAY_OF_WEEK  \
# 0      Collision with a fixed object            4
# 1      Collision with a fixed object            4
# 2             Collision with vehicle            4
# 3                  Struck Pedestrian            5
# 4  Vehicle overturned (no collision)            5
#
#                                             DCA_CODE HIT_RUN_FLAG  \
# 0  OTHER ACCIDENTS ON CURVE NOT INCLUDED IN DCAs ...           No
# 1    LEFT OFF CARRIAGEWAY INTO OBJECT/PARKED VEHICLE           No
# 2                  CROSS TRAFFIC(INTERSECTIONS ONLY)           No
# ...

# %%
crashes_cleaned_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60689 entries, 0 to 60688
# Data columns (total 48 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ACCIDENT_STATUS   60689 non-null  object
#  1   ACCIDENT_DATE     60689 non-null  object
#  2   ACCIDENT_TIME     60689 non-null  object
#  3   ALCOHOLTIME       60689 non-null  object
#  4   ACCIDENT_TYPE     60689 non-null  object
#  5   DAY_OF_WEEK       60689 non-null  int64
#  6   DCA_CODE          60689 non-null  object
#  7   HIT_RUN_FLAG      60689 non-null  object
#  8   LIGHT_CONDITION   60689 non-null  object
#  9   POLICE_ATTEND     60689 non-null  object
#  10  ROAD_GEOMETRY     60689 non-null  object
#  11  SEVERITY          60686 non-null  object
#  12  SPEED_ZONE        60689 non-null  object
#  13  RUN_OFFROAD       60689 non-null  object
#  14  LONGITUDE         60689 non-null  float64
#  15  LATITUDE          60689 non-null  float64
# ...

# %%
# Calculate Pearson correlation coefficients for quantitative data
correlation_matrix = crashes_cleaned_df.corr(method='pearson')

# Display the correlation matrix
print(correlation_matrix)
# Out:
#                   DAY_OF_WEEK  LONGITUDE  LATITUDE  TOTAL_PERSONS  \
# DAY_OF_WEEK          1.000000   0.000146  0.002288       0.011635
# LONGITUDE            0.000146   1.000000 -0.887596       0.007973
# LATITUDE             0.002288  -0.887596  1.000000      -0.029243
# TOTAL_PERSONS        0.011635   0.007973 -0.029243       1.000000
# INJ_OR_FATAL        -0.001788   0.004812 -0.004355       0.543978
# FATALITY            -0.000831  -0.015015  0.029195       0.027409
# SERIOUSINJURY       -0.007959   0.000630 -0.007911       0.155163
# OTHERINJURY          0.005048   0.007238 -0.003501       0.405956
# NONINJURED           0.014038   0.008132 -0.031874       0.845185
# MALES                0.007180   0.006317 -0.016610       0.609174
# FEMALES              0.006729   0.004942 -0.020770       0.678638
# PILLION             -0.005989   0.004688 -0.002381       0.018968
# MOTORIST            -0.007133   0.001084  0.026370      -0.195786
# ...

# %%
import scipy.stats

# calculation of p-values for qualitative data

# Specify the two qualitative columns you want to analyze
column1 = crashes_cleaned_df['LIGHT_CONDITION']
column2 = crashes_cleaned_df['SEVERITY']

# Drop rows with NaN values in either of the columns
# crashes_cleaned_df.dropna(subset=['LIGHT_CONDITION', 'SEVERITY'], inplace=False)

# crashes_cleaned_df.info()


# Create a contingency table
contingency_table = pd.crosstab(column1, column2)

# Calculate the chi-squared statistic and p-value
chi2, p, _, _ = scipy.stats.chi2_contingency(contingency_table)

# print("Chi-squared statistic:", chi2)
print("p-value:", p)
# Out:
# p-value: 2.101511528298224e-150

# %%
# Specify the two qualitative columns you want to analyze
column3 = crashes_cleaned_df['LIGHT_CONDITION']
column4 = crashes_cleaned_df['FATALITY']

crashes_cleaned_df["LIGHT_CONDITION"] = pd.to_numeric(crashes_cleaned_df['LIGHT_CONDITION'], errors='coerce')


# Create a contingency table
contingency_table = pd.crosstab(column3, column4)

# Calculate the chi-squared statistic and p-value
chi2, p, _, _ = scipy.stats.chi2_contingency(contingency_table)

# print("Chi-squared statistic:", chi2)
print("p-value:", p)
# Out:
# p-value: 7.732210833188273e-42

# %%
# Specify the two qualitative columns you want to analyze
column5 = crashes_cleaned_df['SPEED_ZONE']
column6 = crashes_cleaned_df['FATALITY']

crashes_cleaned_df["SPEED_ZONE"] = pd.to_numeric(crashes_cleaned_df['SPEED_ZONE'], errors='coerce')

# Create a contingency table
contingency_table = pd.crosstab(column5, column6)

# Calculate the chi-squared statistic and p-value
chi2, p, _, _ = scipy.stats.chi2_contingency(contingency_table)

# print("Chi-squared statistic:", chi2)
print("p-value:", p)
# Out:
# p-value: 1.1123487679832935e-144

# %%
# Specify the two qualitative columns you want to analyze
column9 = crashes_cleaned_df['ROAD_GEOMETRY']
column10 = crashes_cleaned_df['SEVERITY']


# Create a contingency table
contingency_table = pd.crosstab(column9, column10)

# Calculate the chi-squared statistic and p-value
chi2, p, _, _ = scipy.stats.chi2_contingency(contingency_table)

# print("Chi-squared statistic:", chi2)
print("p-value:", p)
# Out:
# p-value: 5.080170613438933e-71

# %%
# Specify the two qualitative columns you want to analyze
column11 = crashes_cleaned_df['ROAD_GEOMETRY']
column12 = crashes_cleaned_df['FATALITY']

crashes_cleaned_df['ROAD_GEOMETRY'] = pd.to_numeric(crashes_cleaned_df['ROAD_GEOMETRY'], errors='coerce')

# Create a contingency table
contingency_table = pd.crosstab(column11, column12)

# Calculate the chi-squared statistic and p-value
chi2, p, _, _ = scipy.stats.chi2_contingency(contingency_table)

# print("Chi-squared statistic:", chi2)
print("p-value:", p)
# Out:
# p-value: 2.7783855530724306e-31

# %%
# Specify the two qualitative columns you want to analyze
column9 = crashes_cleaned_df['RMA_ALL']
column10 = crashes_cleaned_df['SEVERITY']


# Create a contingency table
contingency_table = pd.crosstab(column9, column10)

# Calculate the chi-squared statistic and p-value
chi2, p, _, _ = scipy.stats.chi2_contingency(contingency_table)

# print("Chi-squared statistic:", chi2)
print("p-value:", p)
# Out:
# p-value: 2.5247091788063975e-73

# %%
# Specify the two qualitative columns you want to analyze
column11 = crashes_cleaned_df['REGION_NAME_ALL']
column12 = crashes_cleaned_df['SEVERITY']


# Create a contingency table
contingency_table = pd.crosstab(column11, column12)

# Calculate the chi-squared statistic and p-value
chi2, p, _, _ = scipy.stats.chi2_contingency(contingency_table)

# print("Chi-squared statistic:", chi2)
print("p-value:", p)
# Out:
# p-value: 2.618877089880544e-144

# %%
# Specify the two qualitative columns you want to analyze
column11 = crashes_cleaned_df["ALCOHOL_RELATED"]
column12 = crashes_cleaned_df['REGION_NAME_ALL']


# Create a contingency table
contingency_table = pd.crosstab(column11, column12)

# Calculate the chi-squared statistic and p-value
chi2, p, _, _ = scipy.stats.chi2_contingency(contingency_table)

# print("Chi-squared statistic:", chi2)
print("p-value:", p)
# Out:
# p-value: 8.349722267524046e-30

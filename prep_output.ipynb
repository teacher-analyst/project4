# %%
import pandas as pd

# %%
original_data = pd.read_csv("Resources/Road_Crashes_for_five_Years_Victoria.csv")
original_data = original_data.drop(columns=["X", "Y", "ACCIDENT_NO", "SRNS", "SRNS_ALL", "DIVIDED", "DIVIDED_ALL", "UNKNOWN", "NODE_ID", "OBJECTID"])
original_data = original_data.dropna()
original_data = original_data.drop(original_data.loc[original_data['REGION_NAME'] == " "].index)
original_data.head()
# Out:
#                   ABS_CODE ACCIDENT_STATUS ACCIDENT_DATE ACCIDENT_TIME  \
# 0  ABS to receive accident        Finished     1/07/2015   05:15:00+00
# 1  ABS to receive accident        Finished     1/07/2015   11:30:00+00
# 2  ABS to receive accident        Finished     1/07/2015   13:40:00+00
# 4  ABS to receive accident        Finished     2/07/2015   10:25:00+00
# 5  ABS to receive accident        Finished     2/07/2015   08:30:00+00
#
#   ALCOHOLTIME                      ACCIDENT_TYPE  DAY_OF_WEEK  \
# 0         Yes      Collision with a fixed object            4
# 1          No      Collision with a fixed object            4
# 2          No             Collision with vehicle            4
# 4          No  Vehicle overturned (no collision)            5
# 5          No             Collision with vehicle            5
#
#                                             DCA_CODE HIT_RUN_FLAG  \
# 0  OTHER ACCIDENTS ON CURVE NOT INCLUDED IN DCAs ...           No
# 1    LEFT OFF CARRIAGEWAY INTO OBJECT/PARKED VEHICLE           No
# 2                  CROSS TRAFFIC(INTERSECTIONS ONLY)           No
# 4                           OFF CARRIAGEWAY TO RIGHT           No
# 5                  CROSS TRAFFIC(INTERSECTIONS ONLY)           No
#
#          LIGHT_CONDITION  ... PASSENGERVEHICLE MOTORCYCLE PUBLICVEHICLE  \
# 0  Dark Street lights on  ...              1.0        0.0           0.0
# 1                    Day  ...              0.0        1.0           0.0
# 2                    Day  ...              2.0        0.0           0.0
# 4                    Day  ...              1.0        0.0           0.0
# 5              Dusk/Dawn  ...              2.0        0.0           0.0
#
#             DEG_URBAN_NAME            DEG_URBAN_ALL  LGA_NAME_ALL  \
# 0  LARGE_PROVINCIAL_CITIES  LARGE_PROVINCIAL_CITIES       GEELONG
# 1               MELB_URBAN               MELB_URBAN    WHITTLESEA
# 2               MELB_URBAN               MELB_URBAN   MARIBYRNONG
# 4           RURAL_VICTORIA           RURAL_VICTORIA   CORANGAMITE
# 5           RURAL_VICTORIA           RURAL_VICTORIA       LATROBE
#
#                   REGION_NAME_ALL             RMA                    RMA_ALL  \
# 0            SOUTH WESTERN REGION      Local Road                 Local Road
# 1  METROPOLITAN NORTH WEST REGION  Arterial Other  Arterial Other,Local Road
# 2  METROPOLITAN NORTH WEST REGION      Local Road                 Local Road
# 4            SOUTH WESTERN REGION  Arterial Other             Arterial Other
# 5   EASTERN REGION,EASTERN REGION  Arterial Other  Local Road,Arterial Other
#
#   STAT_DIV_NAME
# 0       Country
# 1         Metro
# 2         Metro
# 4       Country
# 5       Country
#
# [5 rows x 55 columns]

# %%
deg_group = original_data.groupby('DEG_URBAN_NAME')
deg_group['LGA_NAME'].unique()
# Out:
# DEG_URBAN_NAME
# LARGE_PROVINCIAL_CITIES                         [GEELONG, BENDIGO, BALLARAT]
# MELBOURNE_CBD                                                    [MELBOURNE]
# MELB_URBAN                 [WHITTLESEA, MARIBYRNONG, YARRA, MORNINGTON PE...
# RURAL_VICTORIA             [CORANGAMITE, LATROBE, ARARAT, MOORABOOL, COLA...
# SMALL_CITIES               [HORSHAM, EAST GIPPSLAND, HUME, WODONGA, MELTO...
# SMALL_TOWNS                [(MOUNT BULLER), YARRIAMBIACK, CARDINIA, BENDI...
# TOWNS                      [GLENELG, MOIRA, YARRA RANGES, LATROBE, MITCHE...
# Name: LGA_NAME, dtype: object

# %%
test = deg_group['LGA_NAME'].unique().to_json()

# %%
print(test)
# Out:
# {"LARGE_PROVINCIAL_CITIES":["GEELONG","BENDIGO","BALLARAT"],"MELBOURNE_CBD":["MELBOURNE"],"MELB_URBAN":["WHITTLESEA","MARIBYRNONG","YARRA","MORNINGTON PENINSULA","WHITEHORSE","CASEY","BANYULE","DANDENONG","MONASH","YARRA RANGES","BRIMBANK","BOROONDARA","MANNINGHAM","PORT PHILLIP","FRANKSTON","DAREBIN","STONNINGTON","GLEN EIRA","NILLUMBIK","HUME","KINGSTON","BAYSIDE","MOONEE VALLEY","MELBOURNE","HOBSONS BAY","WYNDHAM","MELTON","MORELAND","KNOX","MAROONDAH","CARDINIA"],"RURAL_VICTORIA":["CORANGAMITE","LATROBE","ARARAT","MOORABOOL","COLAC OTWAY","MACEDON RANGES","INDIGO","MILDURA","MURRINDINDI","MITCHELL","GLENELG","BALLARAT","SOUTH GIPPSLAND","BAW BAW","SURF COAST","MANSFIELD","PYRENEES","HUME","BENDIGO","CARDINIA","HEPBURN","NILLUMBIK","CAMPASPE","MORNINGTON PENINSULA","WELLINGTON","NORTHERN GRAMPIANS","BENALLA","YARRA RANGES","CASEY","WHITTLESEA","TOWONG","WYNDHAM","BASS COAST","GOLDEN PLAINS","SHEPPARTON","GEELONG","MOIRA","MOUNT ALEXANDER","ALPINE","EAST GIPPSLAND","HORSHAM","SOUTHERN GRAMPIANS","MOYNE","YARRIAMBIACK","KNOX","LODDON","MELTON","HINDMARSH","STRATHBOGIE","WANGARATTA","WEST WIMMERA","(LAKE MOUNTAIN)","BULOKE","WODONGA","GANNAWARRA","CENTRAL GOLDFIELDS","SWAN HILL","MANNINGHAM","BRIMBANK","WARRNAMBOOL","(FALLS CREEK)","(FRENCH ISLAND)","(MOUNT STIRLING)","FRANKSTON"],"SMALL_CITIES":["HORSHAM","EAST GIPPSLAND","HUME","WODONGA","MELTON","MILDURA","LATROBE","COLAC OTWAY","MOORABOOL","WELLINGTON","BAW BAW","WANGARATTA","WARRNAMBOOL","GEELONG","SHEPPARTON","CARDINIA","CAMPASPE","SURF COAST"],"SMALL_TOWNS":["(MOUNT BULLER)","YARRIAMBIACK","CARDINIA","BENDIGO","WYNDHAM","CENTRAL GOLDFIELDS","YARRA RANGES","MURRINDINDI","SWAN HILL","SOUTHERN GRAMPIANS","GOLDEN PLAINS","TOWONG","BAW BAW","EAST GIPPSLAND","MANSFIELD","BASS COAST","(MOUNT HOTHAM)","MOORABOOL","INDIGO","MOUNT ALEXANDER","LODDON","ALPINE","NILLUMBIK","MILDURA","CORANGAMITE","MACEDON RANGES","SHEPPARTON","MORNINGTON PENINSULA","SURF COAST","HEPBURN","CASEY","WELLINGTON","MOIRA","PYRENEES","SOUTH GIPPSLAND","COLAC OTWAY","(FALLS CREEK)","HUME","MELTON","WEST WIMMERA","STRATHBOGIE","LATROBE","BULOKE","MANNINGHAM","WANGARATTA","NORTHERN GRAMPIANS","GEELONG","GANNAWARRA","CAMPASPE","WARRNAMBOOL","MOYNE","BALLARAT","(MOUNT BAW BAW)","ARARAT","HINDMARSH"],"TOWNS":["GLENELG","MOIRA","YARRA RANGES","LATROBE","MITCHELL","BAW BAW","BASS COAST","CARDINIA","BENDIGO","ARARAT","SWAN HILL","MACEDON RANGES","MILDURA","SOUTHERN GRAMPIANS","SOUTH GIPPSLAND","BENALLA","WHITTLESEA","GEELONG","SURF COAST","NORTHERN GRAMPIANS","CENTRAL GOLDFIELDS","SHEPPARTON","WELLINGTON","CAMPASPE","MOYNE","HEPBURN","GOLDEN PLAINS","MOUNT ALEXANDER","MELTON","ALPINE","EAST GIPPSLAND","YARRIAMBIACK","STRATHBOGIE","GANNAWARRA","MANNINGHAM","TOWONG","INDIGO","HINDMARSH","WODONGA","COLAC OTWAY","MANSFIELD","CORANGAMITE","MURRINDINDI","CASEY","MORNINGTON PENINSULA","QUEENSCLIFFE","MOORABOOL","BULOKE"]}

# %%
with open("output.json", "w") as outfile:
    outfile.write(test)
